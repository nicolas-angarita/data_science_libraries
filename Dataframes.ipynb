# %%
from pydataset import data
import numpy as np
import pandas as pd

# %%
type(data)
# Out:
# function

# %% [markdown]
# All the datasets loaded from the pydataset library will be pandas dataframes.
#
# 1. Copy the code from the lesson to create a dataframe full of student grades.
#
#  a. Create a column named passing_english that indicates whether each student has a passing grade in english.
#
#  b. Sort the english grades by the passing_english column. How are duplicates handled?
#
#  c. Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered  alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)
#
#  d. Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.
#
#  e. Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df['passing_english'] = df.english > 70
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
df.sort_values('english')
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %%
df.sort_values(['passing_english', 'name'])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %%
df.sort_values(['passing_english', 'english'])
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# e. Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
'''df.describe()
overall_sum = math_grades + english_grades + reading_grades

overall_grade =  np.round(overall_sum / 3, 2)

overall_grade.size

df['average'] = overall_grade

df
'''
# Out:
# "df.describe()\noverall_sum = math_grades + english_grades + reading_grades\n\noverall_grade =  np.round(overall_sum / 3, 2)\n\noverall_grade.size\n\ndf['average'] = overall_grade\n\ndf\n"

# %%
df['overall_grade'] = round((df['math']+df['english']+df['reading'])/3, 2)
df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True          75.67
# 1      Jane    88       79       67             True          78.00
# 2     Suzie    94       74       95             True          87.67
# 3     Billy    98       96       88             True          94.00
# 4       Ada    77       92       98             True          89.00
# 5      John    79       76       93             True          82.67
# 6    Thomas    82       64       81            False          75.67
# 7     Marie    93       63       90            False          82.00
# 8    Albert    92       62       87            False          80.33
# 9   Richard    69       80       94             True          81.00
# 10    Isaac    92       99       93             True          94.67
# 11     Alan    92       62       72            False          75.33

# %% [markdown]
# 2. Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:
#
#  - How many rows and columns are there?
#  - What are the data types of each column?
#  - Summarize the dataframe with .info and .describe
#  - Rename the cty column to city.
#  - Rename the hwy column to highway.
#  - Do any cars have better city mileage than highway mileage?
#  - Create a column named mileage_difference this column should contain the difference between highway and city  mileage for each car.
#  - Which car (or cars) has the highest mileage difference?
#  - Which compact class car has the lowest highway mileage? The best?
#  - Create a column named average_mileage that is the mean of the city and highway mileage.
#  - Which dodge car has the best average mileage? The worst?

# %%
from pydataset import data

# %%
# data('mpg', show_doc=True) # view the documentation for the dataset
mpg = data('mpg') # load the dataset and store it in a variable

# %%
mpg.shape, type(mpg), mpg.dtypes
# Out:
# ((234, 11),
#  pandas.core.frame.DataFrame,
#  manufacturer     object
#  model            object
#  displ           float64
#  year              int64
#  cyl               int64
#  trans            object
#  drv              object
#  cty               int64
#  hwy               int64
#  fl               object
#  class            object
#  dtype: object)

# %%
mpg.info(), mpg.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB
# (None,
#              displ         year         cyl         cty         hwy
#  count  234.000000   234.000000  234.000000  234.000000  234.000000
#  mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# ...

# %%
mpg = mpg.rename(columns={'cty': 'city',
                           'hwy':'highway'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %%
mpg[mpg['city'] > mpg['highway']]
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, highway, fl, class]
# Index: []

# %%
sum(mpg['city'] > mpg['highway'])
# Out:
# 0

# %%
'''difference_mpg = mpg["highway"] - mpg["city"]


mpg['mileage_difference'] = difference_mpg

mpg'''
# Out:
# 'difference_mpg = mpg["highway"] - mpg["city"]\n\n\nmpg[\'mileage_difference\'] = difference_mpg\n\nmpg'

# %%
mpg['mileage_difference'] = mpg['highway'] - mpg['city']

mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  mileage_difference
# ...

# %%
mpg.sort_values('mileage_difference', ascending= False).head(2)
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
#
#     fl       class  mileage_difference
# 107  c  subcompact                  12
# 223  d  subcompact                  12

# %%
#mpg.sort_values(['class', 'mileage_difference'])

compact_cars = mpg['class'] == 'compact'

mpg[compact_cars].sort_values('highway', ascending= False).tail(1)

# lowest highway mileage
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#        class  mileage_difference
# 220  compact                   7

# %%
mpg[compact_cars].sort_values('highway', ascending= False).head(3)

#highest highway mileage
# Out:
#     manufacturer    model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen    jetta    1.9  1999    4  manual(m5)   f    33       44  d
# 197       toyota  corolla    1.8  2008    4  manual(m5)   f    28       37  r
# 196       toyota  corolla    1.8  1999    4  manual(m5)   f    26       35  r
#
#        class  mileage_difference
# 213  compact                  11
# 197  compact                   9
# 196  compact                   9

# %%
mpg[compact_cars].sort_values('highway', ascending= False)
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  city  \
# 213   volkswagen         jetta    1.9  1999    4  manual(m5)   f    33
# 197       toyota       corolla    1.8  2008    4  manual(m5)   f    28
# 196       toyota       corolla    1.8  1999    4  manual(m5)   f    26
# 198       toyota       corolla    1.8  2008    4    auto(l4)   f    26
# 195       toyota       corolla    1.8  1999    4    auto(l4)   f    24
# 189       toyota  camry solara    2.4  2008    4  manual(m5)   f    21
# 3           audi            a4    2.0  2008    4  manual(m6)   f    20
# 190       toyota  camry solara    2.4  2008    4    auto(s5)   f    22
# 4           audi            a4    2.0  2008    4    auto(av)   f    21
# 194       toyota       corolla    1.8  1999    4    auto(l3)   f    24
# 208   volkswagen           gti    2.0  1999    4  manual(m5)   f    21
# 211   volkswagen           gti    2.0  2008    4    auto(s6)   f    22
# ...

# %%
# sum_mpg = mpg["highway"] + mpg["city"]
# average_mileage = np.round(sum_mpg/2, 2)
# mpg['average_mileage'] = average_mileage


mpg['average_mileage'] = (mpg['city'] + mpg['highway'])/2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_difference  average_mileage
# 1  compact                  11             23.5
# 2  compact                   8             25.0
# 3  compact                  11             25.5
# 4  compact                   9             25.5
# 5  compact                  10             21.0

# %%
dodge_car = mpg['manufacturer'] == 'dodge'

mpg[dodge_car].sort_values('average_mileage', ascending= False).head(1)
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl    class  mileage_difference  average_mileage
# 38  r  minivan                   6             21.0

# %%
mpg[dodge_car].sort_values('average_mileage', ascending= False).tail(4)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     highway fl   class  mileage_difference  average_mileage
# 66       12  e  pickup                   3             10.5
# 60       12  e     suv                   3             10.5
# 55       12  e  pickup                   3             10.5
# 70       12  e  pickup                   3             10.5

# %% [markdown]
# 3. Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:
#
#  - How many rows and columns are there?
#  - What are the data types?
#  - Summarize the dataframe with .info and .describe
#  - What is the the weight of the fastest animal?
#  - What is the overal percentage of specials?
#  - How many animals are hoppers that are above the median speed? What percentage is this?

# %%
Mammals = data('Mammals')

# %%
Mammals
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
Mammals.shape, type(Mammals)
# Out:
# ((107, 4), pandas.core.frame.DataFrame)

# %%
Mammals.info(), Mammals.describe()

# data types are floats and bool
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB
# (None,
#              weight       speed
#  count   107.000000  107.000000
#  mean    278.688178   46.208411
#  std     839.608269   26.716778
#  min       0.016000    1.600000
#  25%       1.700000   22.500000
#  50%      34.000000   48.000000
#  75%     142.500000   65.000000
#  max    6000.000000  110.000000)

# %%
Mammals[['speed','weight']].sort_values('speed', ascending= False).head(1)

# 55 kgs
# Out:
#     speed  weight
# 53  110.0    55.0

# %%
special_mammals = Mammals['specials'] == True

count_specials = len(Mammals[special_mammals])

percent_specials = (count_specials / len(special_mammals)) * 100

percent_specials

# Mammals.specials.sum() / len(Mammals) * 100
# Out:
# 9.345794392523365

# %%
Mammals[special_mammals]
# Out:
#      weight  speed  hoppers  specials
# 10   3800.0   25.0    False      True
# 59     12.0   24.0    False      True
# 60     11.0   30.0    False      True
# 65      5.0   27.0    False      True
# 66      3.0   16.0    False      True
# 68     70.0   40.0    False      True
# 69     13.0   37.0    False      True
# 70      9.0    3.2    False      True
# 105     5.0    7.4    False      True
# 107     4.0    1.6    False      True

# %% [markdown]
# - How many animals are hoppers that are above the median speed? What percentage is this?

# %%
med_speed= Mammals['speed'].median()

# %%
hoppers_animals = Mammals['hoppers'] == True

hoppers_animals = Mammals[hoppers_animals]

above_med_speed= hoppers_animals[hoppers_animals['speed'] > med_speed]


percent_hopper_speedy = (len(above_med_speed)/len(hoppers_animals)) * 100

percent_hopper_speedy
# Out:
# 63.63636363636363

# %%
fast_hoppers = len(Mammals[Mammals['hoppers'] & (Mammals['speed'] > Mammals['speed'].median())]) 
hoppers = len(Mammals[Mammals['hoppers']])

# %%
round(fast_hoppers / hoppers * 100, 2)
# Out:
# 63.64
